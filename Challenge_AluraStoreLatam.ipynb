# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd
import matplotlib.pyplot as plt

url1 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url1)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# # **Conociendo el conjunto de datos**

# %%
tienda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %%
tienda2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %%
tienda3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %%
tienda4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2358 entries, 0 to 2357
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2358 non-null   object
#  1   Categoría del Producto  2358 non-null   object
#  2   Precio                  2358 non-null   float64
#  3   Costo de envío          2358 non-null   float64
#  4   Fecha de Compra         2358 non-null   object
#  5   Vendedor                2358 non-null   object
#  6   Lugar de Compra         2358 non-null   object
#  7   Calificación            2358 non-null   int64
#  8   Método de pago          2358 non-null   object
#  9   Cantidad de cuotas      2358 non-null   int64
#  10  lat                     2358 non-null   float64
#  11  lon                     2358 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.2+ KB

# %% [markdown]
# #1. Análisis de facturación

# %%
def ingreso_tienda(dataset):
  return dataset['Precio'].sum()

# %% [markdown]
# #### **Tienda 1**

# %%
ingreso_total_tienda1 = ingreso_tienda(tienda)
ingreso_total_tienda1
# Out:
# np.float64(1150880400.0)

# %% [markdown]
# #### **Tienda 2**

# %%
ingreso_total_tienda2 = ingreso_tienda(tienda2)
ingreso_total_tienda2
# Out:
# np.float64(1116343500.0)

# %% [markdown]
# #### **Tienda 3**

# %%
ingreso_total_tienda3 = ingreso_tienda(tienda3)
ingreso_total_tienda3
# Out:
# np.float64(1098019600.0)

# %% [markdown]
# #### **Tienda 4**

# %%
ingreso_total_tienda4 = ingreso_tienda(tienda4)
ingreso_total_tienda4
# Out:
# np.float64(1038375700.0)

# %% [markdown]
# ##### **Unificación de datos de las tiendas**

# %%
def unificar_datos(serie1, serie2, serie3, serie4, nombreColumna):
  series = {'tienda1' : serie1,
            'tienda2' : serie2,
            'tienda3' : serie3,
            'tienda4' : serie4}
  return pd.Series(series, name = nombreColumna)

# %%
ingresos_totales = unificar_datos(ingreso_total_tienda1, ingreso_total_tienda2, ingreso_total_tienda3, ingreso_total_tienda4, 'Ingresos').astype(int)

ingresos_totales
# Out:
# tienda1    1150880400
# tienda2    1116343500
# tienda3    1098019600
# tienda4    1038375700
# Name: Ingresos, dtype: int64

# %% [markdown]
# #### **Gráfico de barras**

# %%
fig, ingresos = plt.subplots(1, figsize=(8,6))
ingresos.bar(ingresos_totales.index, ingresos_totales.values)
ingresos.set_title("Ingresos totales por tienda", fontsize=20, fontweight='bold')
ingresos.set_xlabel("Tiendas", fontsize=16,fontweight='bold') , ingresos.set_ylabel("Ingreso Totales", fontsize=16,fontweight='bold')

# Mostrar el ingreso total encima de cada una de las barras
for i, valor in enumerate(ingresos_totales.values):
  ingresos.text(i, valor+1, f'{valor:,.0f}', ha='center', va='bottom', fontsize = 10, color='black' )
# Desactivar notación cientifica
ingresos.ticklabel_format(style='plain', axis='y')

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# #### **Agrupar por categorias**

# %%
def agrupar_categoria(dataset):
  return dataset.groupby('Categoría del Producto')['Producto'].count().sort_values(ascending=False)

# %% [markdown]
# #### **Tienda 1**

# %%
tienda1_categorias = agrupar_categoria(tienda)
tienda1_categorias
# Out:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: Producto, dtype: int64

# %% [markdown]
# #### **Tienda 2**

# %%
tienda2_categorias = agrupar_categoria(tienda2)
tienda2_categorias
# Out:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: Producto, dtype: int64

# %% [markdown]
# #### **Tienda 3**

# %%
tienda3_categorias = agrupar_categoria(tienda3)
tienda3_categorias
# Out:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Artículos para el hogar    177
# Instrumentos musicales     177
# Name: Producto, dtype: int64

# %% [markdown]
# #### **Tienda 4**

# %%
tienda4_categorias = agrupar_categoria(tienda4)
tienda4_categorias
# Out:
# Categoría del Producto
# Muebles                    480
# Electrónicos               451
# Juguetes                   338
# Deportes y diversión       277
# Electrodomésticos          254
# Artículos para el hogar    201
# Libros                     187
# Instrumentos musicales     170
# Name: Producto, dtype: int64

# %% [markdown]
# ####  **Grafico de torta**

# %%
fig1, categoria = plt.subplots(2, 2, figsize=(14,8))
fig1.suptitle("Distribución de ventas por categoría de producto", fontsize = 20, fontweight='bold')

categoria[0,0].pie(tienda1_categorias, labels = tienda1_categorias.index, autopct='%1.1f%%', startangle=90, colors=plt.cm.Set3.colors)
categoria[0,0].set_title('Tienda 1', y=-0.2, fontsize = 16, fontweight='bold')
categoria[0,1].pie(tienda2_categorias, labels = tienda2_categorias.index, autopct='%1.1f%%', startangle=90, colors=plt.cm.Set3.colors)
categoria[0,1].set_title('Tienda 2', y=-0.2, fontsize = 16, fontweight='bold')
categoria[1,0].pie(tienda3_categorias, labels = tienda3_categorias.index, autopct='%1.1f%%', startangle=90, colors=plt.cm.Set3.colors)
categoria[1,0].set_title('Tienda 3', y=-0.2, fontsize = 16, fontweight='bold')
categoria[1,1].pie(tienda4_categorias, labels = tienda4_categorias.index, autopct='%1.1f%%', startangle=90, colors=plt.cm.Set3.colors)
categoria[1,1].set_title('Tienda 4', y=-0.2, fontsize = 16, fontweight='bold')
# Out:
# Text(0.5, -0.2, 'Tienda 4')

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
def promedio_calificacion(dataset):
  return dataset['Calificación'].mean()

# %% [markdown]
# #### **Tienda 1**

# %%
calificacion_promedio_tienda1 = promedio_calificacion(tienda)
calificacion_promedio_tienda1
# Out:
# np.float64(3.976685036032217)

# %% [markdown]
# #### **Tienda 2**

# %%
calificacion_promedio_tienda2 = promedio_calificacion(tienda2)
calificacion_promedio_tienda2
# Out:
# np.float64(4.037303942348453)

# %% [markdown]
# #### **Tienda 3**

# %%
calificacion_promedio_tienda3 = promedio_calificacion(tienda3)
calificacion_promedio_tienda3
# Out:
# np.float64(4.048325561678677)

# %% [markdown]
# #### **Tienda 4**

# %%
calificacion_promedio_tienda4 = promedio_calificacion(tienda4)
calificacion_promedio_tienda4
# Out:
# np.float64(3.9957591178965224)

# %% [markdown]
# #### **Unificación de promedios**

# %%
calificaciones_promedio = unificar_datos(calificacion_promedio_tienda1, calificacion_promedio_tienda2, calificacion_promedio_tienda3, calificacion_promedio_tienda4, 'Calificación')
calificaciones_promedio
# Out:
# tienda1    3.976685
# tienda2    4.037304
# tienda3    4.048326
# tienda4    3.995759
# Name: Calificación, dtype: float64

# %% [markdown]
# #### **Gráfico de puntos**

# %%
fig2, calificacion = plt.subplots(figsize=(12,6))
calificacion.scatter(calificaciones_promedio.index, calificaciones_promedio.values, color='red', s=100)
calificacion.set_title("Calificaciones promedio de los clientes por tienda", fontsize=20, fontweight= 'bold')
calificacion.set_xlabel("Tiendas", fontsize=16, fontweight= 'bold')
calificacion.set_ylabel("Calificación promedio", fontsize=16, fontweight= 'bold')
calificacion.set_ylim(3.5,4.2) # Limita el rango del eje y

for i, valor in enumerate(calificaciones_promedio.values):
  calificacion.text(i, valor+0.02, f'{valor:.2f}', ha='center')

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
def prod_mas_vendidos(dataset):
  return dataset.groupby('Producto').size().reset_index(name='Cantidad Vendida').sort_values('Cantidad Vendida', ascending=False).head(3)

def pro_menos_vendidos(dataset):
  return dataset.groupby('Producto').size().reset_index(name='Cantidad Vendida').sort_values('Cantidad Vendida', ascending=True).head(3)

# %% [markdown]
# #### Tienda 1 - Ranking 3 productos más vendidos

# %%
prod_mas_vendidos_tienda1 = prod_mas_vendidos(tienda)
prod_mas_vendidos_tienda1
# Out:
#          Producto  Cantidad Vendida
# 1         Armario                60
# 48  TV LED UHD 4K                60
# 33     Microondas                60

# %% [markdown]
# #### Tienda 1 - Ranking 3 productos menos vendidos

# %%
prod_menos_vendidos_tienda1 = pro_menos_vendidos(tienda)
prod_menos_vendidos_tienda1
# Out:
#                      Producto  Cantidad Vendida
# 4   Auriculares con micrófono                33
# 13               Celular ABXY                33
# 37            Olla de presión                35

# %% [markdown]
# #### Tienda 2 - Ranking 3 productos más vendidos

# %%
prod_mas_vendidos_tienda2 = prod_mas_vendidos(tienda2)
prod_mas_vendidos_tienda2
# Out:
#                      Producto  Cantidad Vendida
# 24  Iniciando en programación                65
# 33                 Microondas                62
# 7                     Batería                61

# %% [markdown]
# #### Tienda 2 - Ranking 3 productos menos vendidos

# %%
prod_menos_vendidos_tienda2 = pro_menos_vendidos(tienda2)
prod_menos_vendidos_tienda2
# Out:
#            Producto  Cantidad Vendida
# 26    Juego de mesa                32
# 23        Impresora                34
# 31  Mesa de comedor                34

# %% [markdown]
# #### Tienda 3 - Ranking 3 productos más vendidos

# %%
prod_mas_vendidos_tienda3 = prod_mas_vendidos(tienda3)
prod_mas_vendidos_tienda3
# Out:
#            Producto  Cantidad Vendida
# 27    Kit de bancas                57
# 31  Mesa de comedor                56
# 11        Cama king                56

# %% [markdown]
# #### Tienda 3 - Ranking 3 productos menos vendidos

# %%
prod_menos_vendidos_tienda3 = pro_menos_vendidos(tienda3)
prod_menos_vendidos_tienda3
# Out:
#                    Producto  Cantidad Vendida
# 9   Bloques de construcción                35
# 42             Set de vasos                36
# 34                  Mochila                36

# %% [markdown]
# #### Tienda 4 - Ranking 3 productos más vendidos

# %%
prod_mas_vendidos_tienda4 = prod_mas_vendidos(tienda4)
prod_mas_vendidos_tienda4
# Out:
#       Producto  Cantidad Vendida
# 10    Cama box                62
# 15  Cubertería                59
# 11   Cama king                56

# %% [markdown]
# #### Tienda 4 - Ranking 3 productos menos vendidos

# %%
prod_menos_vendidos_tienda4 = pro_menos_vendidos(tienda4)
prod_menos_vendidos_tienda4
# Out:
#               Producto  Cantidad Vendida
# 22  Guitarra eléctrica                33
# 1              Armario                34
# 21   Guitarra acústica                37

# %% [markdown]
# #### **Grafico de barras horizontales**

# %%
fig3, productos= plt.subplots(4,1, figsize=(12,10))
fig3.suptitle('Categorías de productos más y menos vendida por cada tienda', fontsize = 17, fontweight='bold')

productos[0].barh(prod_menos_vendidos_tienda1['Producto'], prod_menos_vendidos_tienda1['Cantidad Vendida'], color='red', alpha=0.8)
productos[0].barh(prod_mas_vendidos_tienda1['Producto'], prod_mas_vendidos_tienda1['Cantidad Vendida'], color='green', alpha=0.8)
productos[0].set_title('Tienda 1')

productos[1].barh(prod_menos_vendidos_tienda2['Producto'], prod_menos_vendidos_tienda2['Cantidad Vendida'], color='red', alpha=0.8)
productos[1].barh(prod_mas_vendidos_tienda2['Producto'], prod_mas_vendidos_tienda2['Cantidad Vendida'], color='green', alpha=0.8)
productos[1].set_title('Tienda 2')

productos[2].barh(prod_menos_vendidos_tienda3['Producto'], prod_menos_vendidos_tienda3['Cantidad Vendida'], color='red', alpha=0.8)
productos[2].barh(prod_mas_vendidos_tienda3['Producto'], prod_mas_vendidos_tienda3['Cantidad Vendida'], color='green', alpha=0.8)
productos[2].set_title('Tienda 3')

productos[3].barh(prod_menos_vendidos_tienda4['Producto'], prod_menos_vendidos_tienda4['Cantidad Vendida'], color='red', alpha=0.8)
productos[3].barh(prod_mas_vendidos_tienda4['Producto'], prod_mas_vendidos_tienda4['Cantidad Vendida'], color='green', alpha=0.8)
productos[3].set_title('Tienda 4')


for ax in productos:
  for bars in ax.containers:
    ax.bar_label(bars,fmt='%.0f',label_type='edge',fontsize=9)


fig3.legend(['Menos vendidos', 'Más vendidos'], fontsize = 10, loc='upper right')
plt.tight_layout(rect=[0,0,1,0.96]) # Para ajustar la imagen y que no se superpongan elementos

# %% [markdown]
# # 5. Envío promedio por tienda

# %% [markdown]
# #### **Tienda 1**

# %%
costo_envio_promedio_tienda1 = tienda['Costo de envío'].mean()
costo_envio_promedio_tienda1
# Out:
# np.float64(26018.60958033065)

# %% [markdown]
# #### **Tienda 2**

# %%
costo_envio_promedio_tienda2 = tienda2['Costo de envío'].mean()
costo_envio_promedio_tienda2
# Out:
# np.float64(25216.235693090293)

# %% [markdown]
# #### **Tienda 3**

# %%
costo_envio_promedio_tienda3 = tienda3['Costo de envío'].mean()
costo_envio_promedio_tienda3
# Out:
# np.float64(24805.680373039424)

# %% [markdown]
# #### **Tienda 4**

# %%
costo_envio_promedio_tienda4 = tienda4['Costo de envío'].mean()
costo_envio_promedio_tienda4
# Out:
# np.float64(23459.457167090754)

# %%
costo_envio_promedio = unificar_datos(costo_envio_promedio_tienda1, costo_envio_promedio_tienda2, costo_envio_promedio_tienda3, costo_envio_promedio_tienda4, 'Costo de envío promedio').astype(int)
costo_envio_promedio
# Out:
# tienda1    26018
# tienda2    25216
# tienda3    24805
# tienda4    23459
# Name: Costo de envío promedio, dtype: int64

# %% [markdown]
# #### **Gráfico de barras sobre costo de envío promedio**

# %%
fig, ax = plt.subplots(1, figsize=(8,6))
fig.suptitle('Costo de envío promedio por tienda', fontsize=20, fontweight='bold')

ax.bar(costo_envio_promedio.index, costo_envio_promedio.values)
ax.set_xlabel('Tiendas', fontsize=16,fontweight='bold')
ax.set_ylabel('Costo de envío promedio', fontsize=16,fontweight='bold')

# Mostrar el costo de envío promedio encima de cada una de las barras
for i, valor in enumerate(costo_envio_promedio.values):
  ax.text(i, valor + 1, f'{valor:,.0f}', ha='center', va='bottom', fontsize=10, color='black')

ax.ticklabel_format(style='plain', axis='y')
plt.tight_layout(rect=[0,0,1,0.96])
plt.show()

# %% [markdown]
# # **Conclusión**

# %% [markdown]
# ### Tras el análisis realizado en este informe y considerando el sistema de puntuación propuesto, se pueden establecer las siguientes conclusiones:
#
# * La Tienda 1, aunque lidera en ingresos, se ve afectada negativamente por una baja calificación de los clientes y un elevado costo de envío.
#
# * La Tienda 2 presenta una fuerte concentración de ventas en un número reducido de productos, lo que podría representar un riesgo en términos de sostenibilidad.
#
# * La Tienda 3 se posiciona como la mejor evaluada gracias a su alta calificación y una adecuada diversificación de productos, a pesar de registrar ingresos ligeramente inferiores al resto.
#
# * La Tienda 4 resulta ser la menos eficiente según los criterios analizados. Si bien ofrece el costo de envío más bajo, sus ingresos son los más reducidos, la satisfacción del cliente no destaca y su dependencia de pocos productos limita su competitividad.
#
#
# ### Cabe señalar que, aunque se revisaron las categorías de productos, no se identificaron elementos relevantes que influyeran en la evaluación final. En consecuencia, se recomienda que el Sr. Juan considere vender la Tienda 4 para dar inicio a su nuevo emprendimiento, ya que es la que presenta menor eficiencia en términos generales.
